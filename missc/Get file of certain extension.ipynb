# %%
import os
import shutil
import glob

# %%
initial_folder =r"C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test"
final_folder =r"C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val"
extension = "jpg"

# %%
for files in glob.glob(initial_folder + "/*" + extension):
    print(files)
    shutil.copy(files, final_folder)
# Out:
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0003885_37513.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0003930_37444.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0003975_37528.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004020_31338.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004065_35460.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004110_33517.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004110_37482.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004140_32036.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004140_34776.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004140_37299.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004155_31369.jpg
# C:\Users\Dev Agarwal\Desktop\vehicle_detection\src\val\test\0004155_37539.jpg
# ...
